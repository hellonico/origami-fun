# %% [markdown]
# # Finding and drawing contours
# Finding object by their shape is one of the key reason people usually comes to OpenCV.

# %%
(ns lush-storm
  (:require
    [opencv4.utils :as u]
    [opencv4.colors.html :as color]
    [opencv4.core :refer :all]))
# Out:
# WARNING: reduce already refers to: #'clojure.core/reduce in namespace: lush-storm, being replaced by: #'opencv4.core/reduce
# WARNING: sort already refers to: #'clojure.core/sort in namespace: lush-storm, being replaced by: #'opencv4.core/sort
# WARNING: min already refers to: #'clojure.core/min in namespace: lush-storm, being replaced by: #'opencv4.core/min
# WARNING: merge already refers to: #'clojure.core/merge in namespace: lush-storm, being replaced by: #'opencv4.core/merge
# WARNING: max already refers to: #'clojure.core/max in namespace: lush-storm, being replaced by: #'opencv4.core/max
# WARNING: compare already refers to: #'clojure.core/compare in namespace: lush-storm, being replaced by: #'opencv4.core/compare
# WARNING: repeat already refers to: #'clojure.core/repeat in namespace: lush-storm, being replaced by: #'opencv4.core/repeat
# nil

# %% [markdown]
# ## Finding contour of headphone and drawing rectangles ...

# %%
(def headphones 
  (-> "resources/chapter03/sonyheadphones.jpg"
      (imread IMREAD_REDUCED_COLOR_4)))

(u/>>> headphones)

# %%
(def mask
  (-> headphones 
      clone 
      (cvt-color! COLOR_BGR2GRAY)
 	  (threshold! 250 255 THRESH_BINARY)
      (median-blur! 7)))

(u/>>> mask)

(def masked-input
  (clone headphones))

(set-to masked-input (new-scalar 0 0 0) mask)
(set-to masked-input (new-scalar 255 255 255) (bitwise-not! mask))

(u/>>> masked-input)

# %%
(def contours 
  (new-arraylist))

(find-contours 
  masked-input
  contours 
  (new-mat) ; mask
  RETR_TREE
  CHAIN_APPROX_NONE)
# Out:
# CvException cv::Exception: OpenCV(4.3.0) /home/vagrant/origami-land/opencv-native/opencv/modules/imgproc/src/contours.cpp:197: error: (-210:Unsupported format or combination of formats) [Start]FindContours supports only CV_8UC1 images when mode != CV_RETR_FLOODFILL otherwise supports CV_32SC1 images only in function 'cvStartFindContours_Impl'
#   org.opencv.imgproc.Imgproc.findContours_1 (Imgproc.java:-2)
# Imgproc.java:    -2 org.opencv.imgproc.Imgproc/findContours_1
# Imgproc.java:  6539 org.opencv.imgproc.Imgproc/findContours
#     core.clj:  1338 opencv4.core$find_contours/invokeStatic
#     core.clj:  1336 opencv4.core$find_contours/invoke
#     core.clj:  3206 clojure.core$eval/invokeStatic
#     core.clj:  3202 clojure.core$eval/invoke
#     main.clj:   243 clojure.main$repl$read_eval_print__8572$fn__8575/invoke
#     main.clj:   261 clojure.main$repl$fn__8581/invoke
#     main.clj:   177 clojure.main$repl/doInvoke
#  RestFn.java:  1523 clojure.lang.RestFn/invoke
# ...
