# %% [markdown]
# # 2D Filters

# %%
(ns voiceless-drylands
    (:require
    [opencv4.utils :as u]
    [opencv4.core :refer :all]))
# Out:
# WARNING: reduce already refers to: #'clojure.core/reduce in namespace: voiceless-drylands, being replaced by: #'opencv4.core/reduce
# WARNING: sort already refers to: #'clojure.core/sort in namespace: voiceless-drylands, being replaced by: #'opencv4.core/sort
# WARNING: min already refers to: #'clojure.core/min in namespace: voiceless-drylands, being replaced by: #'opencv4.core/min
# WARNING: merge already refers to: #'clojure.core/merge in namespace: voiceless-drylands, being replaced by: #'opencv4.core/merge
# WARNING: max already refers to: #'clojure.core/max in namespace: voiceless-drylands, being replaced by: #'opencv4.core/max
# WARNING: compare already refers to: #'clojure.core/compare in namespace: voiceless-drylands, being replaced by: #'opencv4.core/compare
# WARNING: repeat already refers to: #'clojure.core/repeat in namespace: voiceless-drylands, being replaced by: #'opencv4.core/repeat
# nil

# %%
(def neko 
  (-> "resources/images/cat.jpg" 
      imread  
      (u/resize-by 0.2)))
# Out:
# #'voiceless-drylands/neko

# %% [markdown]
# ## prewitt-horizontal

# %%
(defn apply-my-filter 
  ([ mat my-filter] 
   (apply-my-filter mat my-filter false))
  ([ mat my-filter invert]
  (->
  mat 
  clone
  (cvt-color! COLOR_RGB2GRAY)
  (filter-2-d! -1 (u/matrix-to-mat my-filter))
  ((fn [x] (if invert (bitwise-not! x) x)))
  (u/>>> ))))

(apply-my-filter neko
     [ [-1 -1 -1]
       [0 0 0]
       [1 1 1]] true)

# %% [markdown]
# ## prewitt-vertical

# %%
(->
  neko 
  clone
  (cvt-color! COLOR_RGB2GRAY)
  (filter-2-d! -1 (u/matrix-to-mat
    [ [-1 0 1]
      [-1 0 1]
      [-1 0 1]]))
  (u/>>> ))

# %%
; sobel vertical-matrix
(->
  (imread "resources/images/cat.jpg")
  (cvt-color! COLOR_RGB2GRAY)
  (filter-2-d! -1 (u/matrix-to-mat
    [ [-1 0 1]
      [-2 0 2]
      [-1 0 1]]))
  (imwrite "output/cat3.png"))

; sobel horizontal
(->
  (imread "resources/images/cat.jpg")
  (cvt-color! COLOR_RGB2GRAY)
  (filter-2-d! -1 (u/matrix-to-mat
    [ [-1 -2 -1]
      [0 0 0]
      [1 2 1]]))
  (imwrite "output/cat3.png"))

; kirsch east
(->
  (imread "resources/images/cat.jpg")
  (cvt-color! COLOR_RGB2GRAY)
  (filter-2-d! -1 (u/matrix-to-mat
    [ [-3 -3 -3]
      [-3 0 -3]
      [5 5 5]]))
  (imwrite "output/cat3.png"))

; kirch southwest
(->
  (imread "resources/images/cat.jpg")
  (cvt-color! COLOR_RGB2GRAY)
  (filter-2-d! -1 (u/matrix-to-mat
    [ [5 5 -3]
      [5 0 -3]
      [-3 -3 -3]]))
  (imwrite "output/cat3.png"))

; robinson north
(->
  (imread "resources/images/cat.jpg")
  (cvt-color! COLOR_RGB2GRAY)
  (filter-2-d! -1 (u/matrix-to-mat
    [ [-1 0 1]
      [-2 0 2]
      [-1 0 1]]))
  (imwrite "output/cat3.png"))

; robinson east
(->
  (imread "resources/images/cat.jpg")
  (cvt-color! COLOR_RGB2GRAY)
  (filter-2-d! -1 (u/matrix-to-mat
    [ [-1 -2 -1]
      [0 0 0]
      [1 2 1]]))
  (imwrite "output/cat3.png"))

; laplacian negative
(->
  (imread "resources/images/cat.jpg")
  (cvt-color! COLOR_RGB2GRAY)
  (filter-2-d! -1 (u/matrix-to-mat
    [ [0 -1 0]
      [-1 4 -1]
      [0 -1 0]]))
  (imwrite "output/cat3.png"))

; laplacian positive
(->
  (imread "resources/images/cat.jpg")
  (cvt-color! COLOR_RGB2GRAY)
  (filter-2-d! -1 (u/matrix-to-mat
    [ [0 1 0]
      [1 4 1]
      [0 1 0]]))
  (imwrite "output/cat3.png"))
# Out:
# #object[org.opencv.core.Mat 0x37b715fa "Mat [ 1200*1600*CV_8UC1, isCont=true, isSubmat=false, nativeObj=0x7f78101353c0, dataAddr=0x7f7810f98240 ]"]
