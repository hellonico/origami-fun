# %% [markdown]
# # Sample Origami Jupyter Notebook

# %%
(ns wooden-winds
   (:require
    [opencv4.core :refer :all]
    [opencv4.utils :as u]))
# Out:
# WARNING: reduce already refers to: #'clojure.core/reduce in namespace: wooden-winds, being replaced by: #'opencv4.core/reduce
# WARNING: sort already refers to: #'clojure.core/sort in namespace: wooden-winds, being replaced by: #'opencv4.core/sort
# WARNING: min already refers to: #'clojure.core/min in namespace: wooden-winds, being replaced by: #'opencv4.core/min
# WARNING: merge already refers to: #'clojure.core/merge in namespace: wooden-winds, being replaced by: #'opencv4.core/merge
# WARNING: max already refers to: #'clojure.core/max in namespace: wooden-winds, being replaced by: #'opencv4.core/max
# WARNING: compare already refers to: #'clojure.core/compare in namespace: wooden-winds, being replaced by: #'opencv4.core/compare
# WARNING: repeat already refers to: #'clojure.core/repeat in namespace: wooden-winds, being replaced by: #'opencv4.core/repeat

# %%
(-> "resources/chapter02/emilie5.jpg"
    imread
    (u/resize-by 0.05)
    u/>>>)

# %% [markdown]
# ## Convert a cat to small picture, in black and white

# %%
(-> "https://r.hswstatic.com/w_907/gif/tesla-cat.jpg"
    u/mat-from-url
    (u/resize-by 0.3)
    (cvt-color! COLOR_RGB2GRAY)
    (u/>>>))
# Out:
# IOException Server returned HTTP response code: 503 for URL: https://r.hswstatic.com/w_907/gif/tesla-cat.jpg  sun.net.www.protocol.http.HttpURLConnection.getInputStream0 (HttpURLConnection.java:1900)
#      HttpURLConnection.java:  1900 sun.net.www.protocol.http.HttpURLConnection/getInputStream0
#      HttpURLConnection.java:  1498 sun.net.www.protocol.http.HttpURLConnection/getInputStream
# HttpsURLConnectionImpl.java:   268 sun.net.www.protocol.https.HttpsURLConnectionImpl/getInputStream
#                   utils.clj:   170 opencv4.utils$image_from_url/invokeStatic
#                   utils.clj:   163 opencv4.utils$image_from_url/invoke
#                   utils.clj:   193 opencv4.utils$mat_from_url/invokeStatic
#                   utils.clj:   191 opencv4.utils$mat_from_url/invoke
#                    core.clj:  3206 clojure.core$eval/invokeStatic
#                    core.clj:  3202 clojure.core$eval/invoke
#                    main.clj:   243 clojure.main$repl$read_eval_print__8572$fn__8575/invoke
#                    main.clj:   261 clojure.main$repl$fn__8581/invoke
#                    main.clj:   177 clojure.main$repl/doInvoke
#                 RestFn.java:  1523 clojure.lang.RestFn/invoke
#                    AFn.java:   152 clojure.lang.AFn/applyToHelper
#                    AFn.java:   144 clojure.lang.AFn/applyTo
#                    core.clj:   657 clojure.core$apply/invokeStatic
#                    core.clj:  1965 clojure.core$with_bindings_STAR_/invokeStatic
#                 RestFn.java:   425 clojure.lang.RestFn/invoke
#                    AFn.java:    22 clojure.lang.AFn/run
#     ThreadPoolExecutor.java:  1149 java.util.concurrent.ThreadPoolExecutor/runWorker
#     ThreadPoolExecutor.java:   624 java.util.concurrent.ThreadPoolExecutor$Worker/run
#                 Thread.java:   748 java.lang.Thread/run
