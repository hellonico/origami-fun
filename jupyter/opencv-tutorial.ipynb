# %% [markdown]
# # Interactive OpenCV Introduction
#
# Manipulate images with clojure and opencv

# %%
(ns spacial-dusk
  (:require 
    [opencv4.core :refer :all]
    [opencv4.utils :as u]))
# Out:
# WARNING: reduce already refers to: #'clojure.core/reduce in namespace: spacial-dusk, being replaced by: #'opencv4.core/reduce
# WARNING: sort already refers to: #'clojure.core/sort in namespace: spacial-dusk, being replaced by: #'opencv4.core/sort
# WARNING: min already refers to: #'clojure.core/min in namespace: spacial-dusk, being replaced by: #'opencv4.core/min
# WARNING: merge already refers to: #'clojure.core/merge in namespace: spacial-dusk, being replaced by: #'opencv4.core/merge
# WARNING: max already refers to: #'clojure.core/max in namespace: spacial-dusk, being replaced by: #'opencv4.core/max
# WARNING: compare already refers to: #'clojure.core/compare in namespace: spacial-dusk, being replaced by: #'opencv4.core/compare
# WARNING: repeat already refers to: #'clojure.core/repeat in namespace: spacial-dusk, being replaced by: #'opencv4.core/repeat
# nil

# %%
(def neko 
  (u/mat-from-url "https://s-media-cache-ak0.pinimg.com/236x/10/2c/75/102c756d7e808deff666f3edf540abba.jpg"))

(u/>>> neko)

# %%
(def gray (new-mat))
(cvt-color neko gray COLOR_RGB2GRAY)
(u/>>> gray)

# %%
(def small-gray-neko 
  (u/resize-by gray 0.5))
(u/>>> small-gray-neko)

# %%
(def equalized (new-mat))
(equalize-hist small-gray-neko equalized)
(u/>>> equalized)

# %%
(def dilated (u/mat-from small-gray-neko))
(def dilation-size 2)
(def element (get-structuring-element  MORPH_RECT
  (new-size (inc (* 2 dilation-size)) (inc (* 2 dilation-size)))))
(dilate small-gray-neko dilated element)
(u/>>> dilated)

# %%
(def sobelled (u/mat-from small-gray-neko))
(sobel small-gray-neko sobelled -1 0 1)
(u/>>> sobelled)

# %%
(def bit_not (u/mat-from small-gray-neko))
(bitwise-not small-gray-neko bit_not)
(u/>>> bit_not)
