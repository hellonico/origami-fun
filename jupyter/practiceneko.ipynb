# %% [markdown]
# # practiceneko Page

# %%
(ns dry-sunrise
  (:require
    [opencv4.utils :as u]
    [opencv4.core :refer :all]))
# Out:
# WARNING: reduce already refers to: #'clojure.core/reduce in namespace: dry-sunrise, being replaced by: #'opencv4.core/reduce
# WARNING: sort already refers to: #'clojure.core/sort in namespace: dry-sunrise, being replaced by: #'opencv4.core/sort
# WARNING: min already refers to: #'clojure.core/min in namespace: dry-sunrise, being replaced by: #'opencv4.core/min
# WARNING: merge already refers to: #'clojure.core/merge in namespace: dry-sunrise, being replaced by: #'opencv4.core/merge
# WARNING: max already refers to: #'clojure.core/max in namespace: dry-sunrise, being replaced by: #'opencv4.core/max
# WARNING: compare already refers to: #'clojure.core/compare in namespace: dry-sunrise, being replaced by: #'opencv4.core/compare
# WARNING: repeat already refers to: #'clojure.core/repeat in namespace: dry-sunrise, being replaced by: #'opencv4.core/repeat
# nil

# %%
(defn load-me[url]
 (-> 
   url
   (imread)
   (cvt-color! COLOR_RGB2GRAY)
   (u/resize-by 0.3)
   (u/>>>)))
# Out:
# #'dry-sunrise/load-me

# %%
(load-me "resources/chapter02/cat.jpg")
