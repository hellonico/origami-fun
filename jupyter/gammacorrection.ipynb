# %% [markdown]
# # Gamma Correction

# %%
(ns squealing-valley
  (:require
    [opencv4.utils :as u]
    [opencv4.core :refer :all]))
# Out:
# WARNING: reduce already refers to: #'clojure.core/reduce in namespace: squealing-valley, being replaced by: #'opencv4.core/reduce
# WARNING: sort already refers to: #'clojure.core/sort in namespace: squealing-valley, being replaced by: #'opencv4.core/sort
# WARNING: min already refers to: #'clojure.core/min in namespace: squealing-valley, being replaced by: #'opencv4.core/min
# WARNING: merge already refers to: #'clojure.core/merge in namespace: squealing-valley, being replaced by: #'opencv4.core/merge
# WARNING: max already refers to: #'clojure.core/max in namespace: squealing-valley, being replaced by: #'opencv4.core/max
# WARNING: compare already refers to: #'clojure.core/compare in namespace: squealing-valley, being replaced by: #'opencv4.core/compare
# WARNING: repeat already refers to: #'clojure.core/repeat in namespace: squealing-valley, being replaced by: #'opencv4.core/repeat
# nil

# %% [markdown]
# ## Create a lookup LUT table from a 1 channel mat

# %%
(defn lookup-mat [_gamma] 
  (let[lut-mat (new-mat 1 256 CV_8UC1) ]
    (doseq [i (range 1 256)]  
      (.put lut-mat 0 i (double-array [(int (* 255 (Math/pow (/ i 255) (/ 1 _gamma))) )] )))
    lut-mat))
# Out:
# #'squealing-valley/lookup-mat

# %% [markdown]
# ## Changing the gamma level equals applying the opencv lut function

# %% [markdown]
# We first create the lookup table from the gamma value and then call the opencv LUT function.

# %%
(defn gamma [img _gamma]
 (let [ out (clone img)]
  (lut img (lookup-mat _gamma) out)
   out))
# Out:
# #'squealing-valley/gamma

# %% [markdown]
# ## Correct Gamma using the above function and a gamma value of 30

# %%
(-> "resources/chapter02/emilie1.jpg"
    (imread)
    (u/resize-by 0.07) 
    (gamma 30) 
    (u/>>>))

# %% [markdown]
# ## Correct Gamma using the gamma function and multiple gamma values

# %%
(let [img (-> "resources/chapter02/emilie1.jpg" (imread) (u/resize-by 0.05) )]
  (u/>>> (hconcat! [img (-> img (gamma 10)) (-> img (gamma 25)) (-> img (gamma 50)) ])))
